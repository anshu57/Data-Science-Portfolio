# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt


from gluonts.mx.trainer import Trainer
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[3], line 6
#       2 import matplotlib as mpl
#       3 import matplotlib.pyplot as plt
# ----> 6 from gluonts.mx.trainer import Trainer
#       7 import numpy as np
#
# File ~/Desktop/Anshu/Data Science Portfolio/.venv/lib/python3.12/site-packages/gluonts/mx/__init__.py:21
#      18 import typing
#      19 from pkgutil import extend_path
# ---> 21 import mxnet as mx
#      23 __path__ = extend_path(__path__, __name__)  # type: ignore
#      25 # Tensor type for HybridBlocks in Gluon
#
# File ~/Desktop/Anshu/Data Science Portfolio/.venv/lib/python3.12/site-packages/mxnet/__init__.py:24
#      21 """MXNet: a concise, fast and flexible framework for deep learning."""
#      22 from __future__ import absolute_import
# ---> 24 from .context import Context, current_context, cpu, gpu, cpu_pinned
#      25 from . import engine
# ...
