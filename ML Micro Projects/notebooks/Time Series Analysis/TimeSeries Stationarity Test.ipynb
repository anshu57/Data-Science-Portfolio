# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import os
from datetime import datetime
import pandas as pd
import plotly.express as px

import warnings
warnings.filterwarnings("ignore")

mpl.rcParams['figure.figsize'] = (10,8)
mpl.rcParams["axes.grid"] = False

# %%
df = pd.read_csv('/Users/anshugangwar/Desktop/Anshu/Data Science Portfolio/ML Micro Projects/data/raw/amazon_revenue_profit.csv')

# %%
df['Quarter'] = pd.to_datetime(df['Quarter'], format='%m/%d/%Y')

# %%
df
# Out:
#       Quarter  Revenue  Net Income
# 0  2020-03-31    75452        2535
# 1  2019-12-31    87437        3268
# 2  2019-09-30    69981        2134
# 3  2019-06-30    63404        2625
# 4  2019-03-31    59700        3561
# ..        ...      ...         ...
# 56 2006-03-31     2279          51
# 57 2005-12-31     2977         199
# 58 2005-09-30     1858          30
# 59 2005-06-30     1753          52
# 60 2005-03-31     1902          78
#
# [61 rows x 3 columns]

# %%
fig = px.line(df, x='Quarter', y='Revenue', title= 'Amazon Revenue Slider')

fig.update_xaxes(
    rangeslider_visible = True
)
fig.show()

# %% [markdown]
# Null Hypothesis - Series is Stationary
# Alternate Hypothesis - Series is not stationary

# %%
from statsmodels.tsa.stattools import kpss

# %%
stats, p , lags, critical_values = kpss(df['Revenue'], regression = 'ct')

# %%
print(f'test Statistics: {stats}')
print(f'p-value: {p}')
print(f'lags: {lags}')
print(f'critical values: {critical_values}')


if p< 0.05 :
    print("Series is not stationary")
else:
    print("Series is stationary")
# Out:
# test Statistics: 0.3066554597516947
# p-value: 0.01
# lags: 4
# critical values: {'10%': 0.119, '5%': 0.146, '2.5%': 0.176, '1%': 0.216}
# Series is not stationary

# %%
# Null Hypothesis - Series possesses a unit root and hence is not stationary
# Alternate Hypothesis - Series is stationary

# %%
from statsmodels.tsa.stattools import adfuller
result = adfuller(df['Revenue'])

# %%
print(f'test Statistics: {result[0]}')
print(f'p-value: {result[1]}')
print(f'critical values: {result[4]}')


if result[1] >0.05 :
    print("Series is not stationary")
else:
    print("Series is stationary")
# Out:
# test Statistics: -2.4448360381972423
# p-value: 0.12947943121838534
# critical values: {'1%': np.float64(-3.568485864), '5%': np.float64(-2.92135992), '10%': np.float64(-2.5986616)}
# Series is not stationary

# %% [markdown]
# we cannot use ARMA model
# we will use ARIMA model
